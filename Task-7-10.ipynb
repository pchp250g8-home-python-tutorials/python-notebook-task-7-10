# %% [markdown]
# Найти сумму S = 1/2+2/2^2+3/2^3+4/2^4+...+100/2^100

# %%
from sympy import Eq
from sympy import solve
from sympy import symbols
from sympy import Sum

n = symbols("n")
sum1 = Sum(n / 2**n, (n, 1, 100))
print(sum1)
print("res =",sum1.doit())
# Out:
# Sum(n/2**n, (n, 1, 100))
# res = 1267650600228229401496703205325/633825300114114700748351602688
